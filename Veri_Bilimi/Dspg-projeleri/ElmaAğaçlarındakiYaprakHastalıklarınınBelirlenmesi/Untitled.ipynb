# %%
import pandas as pd
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# %%
train_data=pd.read_csv("data/train.csv")
test_data = pd.read_csv("data/test.csv")

# %%
data=[]

for name in train_data['image_id']:
    data.append(Image.open(f"data/images/{name}.jpg").__array__())

# %%
print(f"data/images/{train_data['image_id']}.jpg")
# Out:
# data/images/0          Train_0
# 1          Train_1
# 2          Train_2
# 3          Train_3
# 4          Train_4
#            ...
# 1816    Train_1816
# 1817    Train_1817
# 1818    Train_1818
# 1819    Train_1819
# 1820    Train_1820
# Name: image_id, Length: 1821, dtype: object.jpg

# %%
data[0].
# Out:
# array([[[ 33,  51,  13],
#         [ 33,  51,  13],
#         [ 33,  51,  13],
#         ...,
#         [ 51,  61,  27],
#         [ 51,  61,  27],
#         [ 51,  61,  27]],
#
#        [[ 33,  51,  13],
#         [ 33,  51,  13],
#         [ 33,  51,  13],
#         ...,
#         [ 50,  60,  26],
#         [ 50,  60,  26],
#         [ 50,  60,  26]],
#
#        [[ 33,  51,  13],
#         [ 33,  51,  13],
#         [ 33,  51,  13],
#         ...,
#         [ 50,  60,  26],
#         [ 50,  60,  26],
#         [ 50,  60,  26]],
#
#        ...,
#
#        [[181, 167, 120],
#         [182, 168, 121],
#         [182, 168, 121],
#         ...,
#         [199, 206, 152],
#         [197, 202, 148],
#         [196, 201, 145]],
#
#        [[181, 167, 120],
#         [182, 168, 121],
#         [182, 168, 121],
#         ...,
#         [199, 207, 156],
#         [198, 205, 153],
#         [202, 206, 155]],
#
#        [[181, 167, 120],
#         [182, 168, 121],
#         [182, 168, 121],
#         ...,
#         [205, 213, 164],
#         [206, 212, 164],
#         [210, 216, 168]]], dtype=uint8)

# %%
fig,axis = plt.subplots(nrows=1,ncols=3)
fig.set_size_inches(16,16)
axis[0].imshow(blue)
axis[1].imshow(red)
axis[2].imshow(green)
fig.show()
# Out:
# /tmp/ipykernel_34517/3564112132.py:6: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
